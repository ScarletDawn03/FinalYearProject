# %%
# Importing the required libraries
import numpy as np
import pandas as pd
import yfinance as yf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, RMSprop

import tensorflow as tf
import csv

from itertools import combinations

# Error Suppression
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

from sklearn.model_selection import ParameterGrid

# Define the fixed hyperparameters
fixed_params = {
    'filters': 64,  # Number of filters in Conv1D layers
    'kernel_size': 3,  # Kernel size for Conv1D layers
    'dropout_rate': 0.2,  # Dropout rate
    'learning_rate': 0.001,  # Learning rate
    'batch_size': 32,  # Batch size
    'epochs': 50,  # Number of epochs
    'optimizer': 'adam'  # Optimizer
}


def download_stock_data(ticker, start_date='2010-01-01', end_date='2024-12-31'):
    # Calculate extra buffer period (e.g., 1 year)
    buffer_start = pd.to_datetime(start_date) - pd.DateOffset(years=1)
    
    # Download data with buffer period
    data = yf.download(ticker, start=buffer_start.strftime('%Y-%m-%d'), end=end_date)

    # Fetch earnings report dates
    ticker_data = yf.Ticker(ticker)
    earnings_dates = set(pd.to_datetime(ticker_data.earnings_dates.index).normalize())  # Normalize dates

    # Fetch ex-dividend dates
    ex_dividend_dates = set(pd.to_datetime(ticker_data.dividends.index).normalize())

    # Combine both sets
    dates_to_remove = earnings_dates.union(ex_dividend_dates)

    # Ensure data index is datetime and normalized
    data.index = pd.to_datetime(data.index).normalize()

    # Remove both earnings & ex-dividend dates
    data = data[~data.index.isin(dates_to_remove)]

    # Trim the dataset to the actual requested start_date
    data = data.loc[start_date:]

    print(dates_to_remove)

    return data

def add_technical_indicators(ticker, df):
    # Ensure calculations don't cause issues with chained assignments
    pd.options.mode.chained_assignment = None  

    # Moving Averages
    df['20MA'] = df['Close'].rolling(window=20, min_periods=1).mean()
    df['50MA'] = df['Close'].rolling(window=50, min_periods=1).mean()
    df['200MA'] = df['Close'].rolling(window=200, min_periods=1).mean()

    # Relative Strength Index (RSI)
    delta = df['Close'].diff()
    gain = delta.where(delta > 0, 0).rolling(window=14, min_periods=1).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14, min_periods=1).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))
    df['RSI'].fillna(50, inplace=True)

    # MACD and Signal Line
    df['12EMA'] = df['Close'].ewm(span=12, adjust=False, min_periods=1).mean()
    df['26EMA'] = df['Close'].ewm(span=26, adjust=False, min_periods=1).mean()
    df['MACD'] = df['12EMA'] - df['26EMA']
    df['Signal_Line'] = df['MACD'].ewm(span=9, adjust=False, min_periods=1).mean()

    # Bollinger Bands
    df['20STD'] = df['Close'].rolling(window=20, min_periods=1).std()
    df['Upper_BB'] = df['20MA'] + (df['20STD'] * 2)
    df['Lower_BB'] = df['20MA'] - (df['20STD'] * 2)

    # Commodity Channel Index (CCI)
    typical_price = (df['High'] + df['Low'] + df['Close']) / 3
    mean_dev = lambda x: np.mean(np.abs(x - np.mean(x)))
    df['CCI'] = (typical_price - typical_price.rolling(window=20, min_periods=1).mean()) / \
                (0.015 * typical_price.rolling(window=20, min_periods=1).apply(mean_dev, raw=True))

    # Average True Range (ATR)
    df['TR'] = np.maximum(df['High'] - df['Low'], 
                          np.maximum(abs(df['High'] - df['Close'].shift(1)), 
                                     abs(df['Low'] - df['Close'].shift(1))))
    df['ATR'] = df['TR'].rolling(window=14, min_periods=1).mean()
    df.drop(columns=['TR'], inplace=True)  # Drop intermediate column

    # Rate of Change (ROC)
    df['ROC'] = df['Close'].pct_change(periods=10) * 100

    # Williams %R
    df['Williams_%R'] = ((df['High'].rolling(window=14, min_periods=1).max() - df['Close']) / 
                          (df['High'].rolling(window=14, min_periods=1).max() - df['Low'].rolling(window=14, min_periods=1).min())) * -100

    # On-Balance Volume (OBV)
    df['OBV'] = (np.sign(df['Close'].diff()) * df['Volume']).fillna(0).cumsum()

    # Drop intermediate columns
    df.drop(columns=['20STD'], inplace=True)

    # Forward-fill and backward-fill NaN values
    df.ffill(inplace=True)
    df.bfill(inplace=True)

    # Verify no NaN values exist
    print("Null values in each column:\n", df.isnull().sum())
    print(f"Does the dataset contain any null values? {df.isnull().values.any()}")

    folder_name = "check"
    os.makedirs(folder_name, exist_ok=True)
    filename = os.path.join(folder_name, f"{ticker}_CNN.csv")
    df.to_csv(filename, index=False)

    return df  # Original DataFrame is modified, so return is optional

def normalize_data(df):
    all_indicators = [
        '20MA', '50MA', '200MA', 'RSI', 'MACD', 'Signal_Line', 
        'Upper_BB', 'Lower_BB', 'CCI', 'ATR', 'ROC', 'Williams_%R', 'OBV'
    ]

    # Generate all possible combinations of 5 indicators + 'Close'
    indicator_combinations = list(combinations(all_indicators, 5))

    # Dictionary to store performance results
    results = {}

    all_scaled_data = {}  # Dictionary to store scaled data for each combination

    for selected_indicators in indicator_combinations:
        selected_features = ['Close'] + list(selected_indicators)  # Always include Close

        # Normalize selected features
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_data = scaler.fit_transform(df[selected_features])

        # Store the scaled data
        all_scaled_data[selected_indicators] = scaled_data

    return df, all_scaled_data  # Return the full dataset and all scaled variations

# Prepare the time-series data
def create_time_series_data(df, scaled_data, window_size=120):
    X, y = [], []
    for i in range(window_size, len(df)):
        X.append(scaled_data[i-window_size:i])
        y.append(df['Close'].iloc[i])
    return np.array(X), np.array(y)

# Split data into training and testing sets (80% training,20% testing)
def split_data(X, y, train_size=0.7, val_size=0.1, test_size=0.2):
    train_end = int(len(X) * train_size)
    val_end = train_end + int(len(X) * val_size)

    X_train, y_train = X[:train_end], y[:train_end]
    X_val, y_val = X[train_end:val_end], y[train_end:val_end]
    X_test, y_test = X[val_end:], y[val_end:]

    return X_train, X_val, X_test, y_train, y_val, y_test

# Function to create a CNN model with fixed hyperparameters
def create_cnn_model(input_shape, params=fixed_params):
    # Initialize the model
    model = Sequential()

    # Add Input layer
    model.add(Input(shape=input_shape))

    # First Conv1D layer
    model.add(Conv1D(filters=params['filters'], kernel_size=params['kernel_size'], activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(rate=params['dropout_rate']))

    # Second Conv1D layer
    model.add(Conv1D(filters=params['filters'], kernel_size=params['kernel_size'], activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(rate=params['dropout_rate']))

    # Flatten the output
    model.add(Flatten())

    # Output layer
    model.add(Dense(units=1))  # Assuming you're predicting a single value

    # Choose optimizer
    if params['optimizer'] == 'adam':
        opt = Adam(learning_rate=params['learning_rate'])
    elif params['optimizer'] == 'rmsprop':
        opt = RMSprop(learning_rate=params['learning_rate'])
    else:
        raise ValueError("Optimizer must be 'adam' or 'rmsprop'.")

    # Compile the model
    model.compile(optimizer=opt, loss='mean_squared_error')

    return model

# Define tickers
tickers = ['AAPL', 'BRK-B', 'XOM',  '1155.KL',  '0270.KL', '5681.KL']

# Dictionary to store results
results = {}

# Define the output folder
output_folder = "stock_results"
os.makedirs(output_folder, exist_ok=True)  # Ensure folder exists

for ticker in tickers:
    print(f"Running model for {ticker}...\n")

    df = download_stock_data(ticker)
    df = add_technical_indicators(ticker, df)
    df, all_scaled_data = normalize_data(df)

    output_file = os.path.join(output_folder, f"{ticker}_results_CNN.csv")

    with open(output_file, mode='w', newline='') as file:
        header = ["Ticker", "Indicators", "Filters", "Kernel Size", "Dropout Rate", "Learning Rate", "Batch Size", "Epochs", "Optimizer", "MSE", "RMSE", "MAE", "MAPE"]
        writer = csv.writer(file)
        writer.writerow(header)  # Write header

        for selected_indicators, scaled_data in all_scaled_data.items():
            print(f"Training with indicators: {selected_indicators} and fixed parameters: {fixed_params}")
            X, y = create_time_series_data(df, scaled_data)

            X_train, X_val, X_test, y_train, y_val, y_test = split_data(X, y)

            # Scale target values (y)
            scaler_y = MinMaxScaler(feature_range=(0, 1))
            y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1))
            y_val_scaled = scaler_y.transform(y_val.reshape(-1, 1))
            y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1))

            input_shape = (X_train.shape[1], X_train.shape[2])  # Input shape for CNN

            # Create and train the model with the fixed hyperparameters
            model = create_cnn_model(input_shape=input_shape)

            early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

            history = model.fit(
                X_train, y_train_scaled,
                epochs=fixed_params['epochs'],
                batch_size=fixed_params['batch_size'],
                validation_data=(X_val, y_val_scaled),
                callbacks=[early_stopping],
                verbose=0
            )

            # Evaluate the model
            y_pred_scaled = model.predict(X_test)
            y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1))
            y_test_original = scaler_y.inverse_transform(y_test_scaled)

            mse = mean_squared_error(y_test_original, y_pred)
            rmse = np.sqrt(mse)
            mae = mean_absolute_error(y_test_original, y_pred)
            mape = mean_absolute_percentage_error(y_test_original, y_pred) * 100

            # Write the results to the CSV file
            writer.writerow([
                ticker,  # Ticker symbol
                ', '.join(selected_indicators),  # Selected indicators
                fixed_params['filters'],  # Filters
                fixed_params['kernel_size'],  # Kernel size
                fixed_params['dropout_rate'],  # Dropout rate
                fixed_params['learning_rate'],  # Learning rate
                fixed_params['batch_size'],  # Batch size
                fixed_params['epochs'],  # Number of epochs
                fixed_params['optimizer'],  # Optimizer
                mse,  # MSE
                rmse,  # RMSE
                mae,  # MAE
                mape  # MAPE
            ])

            # Flush the file buffer to ensure data is written
            file.flush()

            print(f"{ticker} - RMSE: {rmse:.4f}, MSE: {mse:.4f}, MAE: {mae:.4f}, MAPE: {mape:.4f}\n")
# Out:
# 2025-03-17 21:47:57.492472: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-17 21:47:58.051219: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-17 21:48:00.402924: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Running model for AAPL...
#
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# {Timestamp('1991-11-18 00:00:00-0500', tz='America/New_York'), Timestamp('2023-05-03 00:00:00-0400', tz='America/New_York'), Timestamp('2024-11-08 00:00:00-0500', tz='America/New_York'), Timestamp('2014-02-06 00:00:00-0500', tz='America/New_York'), Timestamp('1995-05-26 00:00:00-0400', tz='America/New_York'), Timestamp('1990-11-16 00:00:00-0500', tz='America/New_York'), Timestamp('2019-11-07 00:00:00-0500', tz='America/New_York'), Timestamp('2022-11-04 00:00:00-0400', tz='America/New_York'), Timestamp('2022-05-06 00:00:00-0400', tz='America/New_York'), Timestamp('1987-08-10 00:00:00-0400', tz='America/New_York'), Timestamp('2019-05-10 00:00:00-0400', tz='America/New_York'), Timestamp('2015-11-05 00:00:00-0500', tz='America/New_York'), Timestamp('2021-02-05 00:00:00-0500', tz='America/New_York'), Timestamp('2024-07-31 00:00:00-0400', tz='America/New_York'), Timestamp('2025-10-28 00:00:00-0400', tz='America/New_York'), Timestamp('2014-05-08 00:00:00-0400', tz='America/New_York'), Timestamp('2024-05-01 00:00:00-0400', tz='America/New_York'), Timestamp('2020-11-06 00:00:00-0500', tz='America/New_York'), Timestamp('2018-02-09 00:00:00-0500', tz='America/New_York'), Timestamp('1990-05-21 00:00:00-0400', tz='America/New_York'), Timestamp('2023-05-12 00:00:00-0400', tz='America/New_York'), Timestamp('1991-08-19 00:00:00-0400', tz='America/New_York'), Timestamp('2013-11-06 00:00:00-0500', tz='America/New_York'), Timestamp('2021-05-07 00:00:00-0400', tz='America/New_York'), Timestamp('2015-08-06 00:00:00-0400', tz='America/New_York'), Timestamp('1994-11-18 00:00:00-0500', tz='America/New_York'), Timestamp('2022-08-05 00:00:00-0400', tz='America/New_York'), Timestamp('1994-02-07 00:00:00-0500', tz='America/New_York'), Timestamp('2016-11-03 00:00:00-0400', tz='America/New_York'), Timestamp('2025-01-29 00:00:00-0500', tz='America/New_York'), Timestamp('1992-11-30 00:00:00-0500', tz='America/New_York'), Timestamp('2014-11-06 00:00:00-0500', tz='America/New_York'), Timestamp('2020-02-07 00:00:00-0500', tz='America/New_York'), Timestamp('1992-08-17 00:00:00-0400', tz='America/New_York'), Timestamp('1993-02-12 00:00:00-0500', tz='America/New_York'), Timestamp('2024-08-12 00:00:00-0400', tz='America/New_York'), Timestamp('2023-02-10 00:00:00-0500', tz='America/New_York'), Timestamp('1989-08-21 00:00:00-0400', tz='America/New_York'), Timestamp('1990-02-16 00:00:00-0500', tz='America/New_York'), Timestamp('2017-11-10 00:00:00-0500', tz='America/New_York'), Timestamp('2023-08-11 00:00:00-0400', tz='America/New_York'), Timestamp('1993-05-28 00:00:00-0400', tz='America/New_York'), Timestamp('1989-11-17 00:00:00-0500', tz='America/New_York'), Timestamp('1988-08-15 00:00:00-0400', tz='America/New_York'), Timestamp('1994-08-15 00:00:00-0400', tz='America/New_York'), Timestamp('2017-08-10 00:00:00-0400', tz='America/New_York'), Timestamp('2015-05-07 00:00:00-0400', tz='America/New_York'), Timestamp('2017-02-09 00:00:00-0500', tz='America/New_York'), Timestamp('2016-08-04 00:00:00-0400', tz='America/New_York'), Timestamp('1993-11-19 00:00:00-0500', tz='America/New_York'), Timestamp('2024-01-31 00:00:00-0500', tz='America/New_York'), Timestamp('2023-11-01 00:00:00-0400', tz='America/New_York'), Timestamp('2016-05-05 00:00:00-0400', tz='America/New_York'), Timestamp('2013-08-08 00:00:00-0400', tz='America/New_York'), Timestamp('2019-02-08 00:00:00-0500', tz='America/New_York'), Timestamp('2023-08-02 00:00:00-0400', tz='America/New_York'), Timestamp('2026-01-27 00:00:00-0500', tz='America/New_York'), Timestamp('2013-05-09 00:00:00-0400', tz='America/New_York'), Timestamp('2020-05-08 00:00:00-0400', tz='America/New_York'), Timestamp('2015-02-05 00:00:00-0500', tz='America/New_York'), Timestamp('2025-04-29 00:00:00-0400', tz='America/New_York'), Timestamp('1989-05-22 00:00:00-0400', tz='America/New_York'), Timestamp('1995-08-16 00:00:00-0400', tz='America/New_York'), Timestamp('2024-02-09 00:00:00-0500', tz='America/New_York'), Timestamp('1987-11-17 00:00:00- ...
# Null values in each column:
#  Price        Ticker
# Close        AAPL      0
# High         AAPL      0
# Low          AAPL      0
# Open         AAPL      0
# Volume       AAPL      0
# 20MA                   0
# 50MA                   0
# 200MA                  0
# RSI                    0
# 12EMA                  0
# 26EMA                  0
# MACD                   0
# Signal_Line            0
# Upper_BB               0
# Lower_BB               0
# CCI                    0
# ATR                    0
# ROC                    0
# Williams_%R            0
# OBV                    0
# dtype: int64
# Does the dataset contain any null values? False
# Training with indicators: ('20MA', '50MA', '200MA', 'RSI', 'MACD') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 21.6886, MSE: 470.3956, MAE: 17.9488, MAPE: 11.1739
#
# Training with indicators: ('20MA', '50MA', '200MA', 'RSI', 'Signal_Line') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 17.5810, MSE: 309.0908, MAE: 14.8479, MAPE: 8.8041
#
# Training with indicators: ('20MA', '50MA', '200MA', 'RSI', 'Upper_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 21.9707, MSE: 482.7131, MAE: 18.3207, MAPE: 9.6967
#
# Training with indicators: ('20MA', '50MA', '200MA', 'RSI', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 17.4914, MSE: 305.9507, MAE: 13.9237, MAPE: 7.4111
#
# Training with indicators: ('20MA', '50MA', '200MA', 'RSI', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 18.3010, MSE: 334.9269, MAE: 15.0433, MAPE: 8.5323
#
# Training with indicators: ('20MA', '50MA', '200MA', 'RSI', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 18.0914, MSE: 327.2993, MAE: 14.6788, MAPE: 7.8789
#
# Training with indicators: ('20MA', '50MA', '200MA', 'RSI', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 21.4606, MSE: 460.5578, MAE: 17.5156, MAPE: 9.4565
#
# Training with indicators: ('20MA', '50MA', '200MA', 'RSI', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 21.4969, MSE: 462.1157, MAE: 17.4837, MAPE: 9.2869
#
# Training with indicators: ('20MA', '50MA', '200MA', 'RSI', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 19.6812, MSE: 387.3506, MAE: 17.3856, MAPE: 10.5330
#
# Training with indicators: ('20MA', '50MA', '200MA', 'MACD', 'Signal_Line') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 24.3478, MSE: 592.8152, MAE: 21.0359, MAPE: 12.9101
#
# Training with indicators: ('20MA', '50MA', '200MA', 'MACD', 'Upper_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AAPL - RMSE: 15.7601, MSE: 248.3802, MAE: 13.1798, MAPE: 7.9693
#
# Training with indicators: ('20MA', '50MA', '200MA', 'MACD', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 14.9665, MSE: 223.9961, MAE: 12.5423, MAPE: 7.4454
#
# Training with indicators: ('20MA', '50MA', '200MA', 'MACD', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 12.9219, MSE: 166.9754, MAE: 10.7539, MAPE: 6.3448
#
# Training with indicators: ('20MA', '50MA', '200MA', 'MACD', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 15.9673, MSE: 254.9561, MAE: 13.1994, MAPE: 7.7910
#
# Training with indicators: ('20MA', '50MA', '200MA', 'MACD', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 27.0666, MSE: 732.5986, MAE: 22.4152, MAPE: 14.0677
#
# Training with indicators: ('20MA', '50MA', '200MA', 'MACD', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AAPL - RMSE: 35.4215, MSE: 1254.6804, MAE: 31.0440, MAPE: 16.5384
#
# Training with indicators: ('20MA', '50MA', '200MA', 'MACD', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 14.8753, MSE: 221.2732, MAE: 12.0322, MAPE: 7.3612
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Signal_Line', 'Upper_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 27.1649, MSE: 737.9307, MAE: 24.2099, MAPE: 14.6044
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Signal_Line', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 28.2480, MSE: 797.9496, MAE: 24.7753, MAPE: 14.9633
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Signal_Line', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 14.1059, MSE: 198.9776, MAE: 11.9158, MAPE: 7.3594
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Signal_Line', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 30.3902, MSE: 923.5624, MAE: 25.8952, MAPE: 13.7283
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Signal_Line', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 25.5003, MSE: 650.2662, MAE: 21.1990, MAPE: 11.1756
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Signal_Line', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 24.7819, MSE: 614.1409, MAE: 20.1466, MAPE: 10.6545
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Signal_Line', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 18.5077, MSE: 342.5332, MAE: 15.2757, MAPE: 8.1625
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Upper_BB', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 9.7582, MSE: 95.2234, MAE: 7.6432, MAPE: 4.6459
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Upper_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 16.0309, MSE: 256.9896, MAE: 13.3586, MAPE: 8.0073
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Upper_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 14.2159, MSE: 202.0927, MAE: 11.0749, MAPE: 6.2237
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Upper_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 18.2555, MSE: 333.2635, MAE: 15.3505, MAPE: 8.6436
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Upper_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 47.9948, MSE: 2303.5022, MAE: 44.1541, MAPE: 24.0782
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Upper_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 26.3968, MSE: 696.7929, MAE: 23.0334, MAPE: 13.9754
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Lower_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 15.2396, MSE: 232.2447, MAE: 12.2774, MAPE: 7.6701
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Lower_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 13.8705, MSE: 192.3911, MAE: 11.0100, MAPE: 6.2072
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Lower_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 16.3583, MSE: 267.5939, MAE: 13.4631, MAPE: 8.1409
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Lower_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 49.8120, MSE: 2481.2343, MAE: 46.9027, MAPE: 25.7670
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Lower_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 18.2210, MSE: 332.0058, MAE: 14.7987, MAPE: 9.1906
#
# Training with indicators: ('20MA', '50MA', '200MA', 'CCI', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 18.4122, MSE: 339.0090, MAE: 14.7135, MAPE: 7.8702
#
# Training with indicators: ('20MA', '50MA', '200MA', 'CCI', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 17.8543, MSE: 318.7772, MAE: 14.5741, MAPE: 8.9411
#
# Training with indicators: ('20MA', '50MA', '200MA', 'CCI', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 26.9784, MSE: 727.8329, MAE: 23.1055, MAPE: 14.4224
#
# Training with indicators: ('20MA', '50MA', '200MA', 'CCI', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 10.9263, MSE: 119.3842, MAE: 8.6222, MAPE: 4.7779
#
# Training with indicators: ('20MA', '50MA', '200MA', 'ATR', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 28.0205, MSE: 785.1512, MAE: 23.5955, MAPE: 12.5518
#
# Training with indicators: ('20MA', '50MA', '200MA', 'ATR', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 53.1794, MSE: 2828.0457, MAE: 48.2653, MAPE: 25.9804
#
# Training with indicators: ('20MA', '50MA', '200MA', 'ATR', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 19.1868, MSE: 368.1339, MAE: 16.5756, MAPE: 9.8399
#
# Training with indicators: ('20MA', '50MA', '200MA', 'ROC', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 34.0270, MSE: 1157.8353, MAE: 29.4002, MAPE: 15.6230
#
# Training with indicators: ('20MA', '50MA', '200MA', 'ROC', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 19.5252, MSE: 381.2329, MAE: 15.7285, MAPE: 8.5348
#
# Training with indicators: ('20MA', '50MA', '200MA', 'Williams_%R', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 37.3160, MSE: 1392.4808, MAE: 35.1614, MAPE: 19.4352
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'MACD', 'Signal_Line') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 31.9737, MSE: 1022.3170, MAE: 27.1888, MAPE: 16.5206
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'MACD', 'Upper_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 19.1858, MSE: 368.0954, MAE: 16.0213, MAPE: 9.8223
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'MACD', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 16.0125, MSE: 256.4015, MAE: 13.1525, MAPE: 7.6124
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'MACD', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 21.5739, MSE: 465.4320, MAE: 17.4700, MAPE: 9.3404
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'MACD', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 29.0484, MSE: 843.8118, MAE: 24.2015, MAPE: 12.8405
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'MACD', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 20.6273, MSE: 425.4853, MAE: 16.4150, MAPE: 8.8036
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'MACD', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AAPL - RMSE: 23.6831, MSE: 560.8913, MAE: 19.3249, MAPE: 11.2749
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'MACD', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 19.0690, MSE: 363.6262, MAE: 15.6852, MAPE: 9.7098
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Signal_Line', 'Upper_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 15.0368, MSE: 226.1048, MAE: 12.3801, MAPE: 7.1972
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Signal_Line', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 16.2588, MSE: 264.3493, MAE: 13.7338, MAPE: 7.9994
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Signal_Line', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 17.8079, MSE: 317.1225, MAE: 14.8522, MAPE: 8.6356
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Signal_Line', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 22.4873, MSE: 505.6808, MAE: 18.1204, MAPE: 9.7100
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Signal_Line', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 29.0925, MSE: 846.3743, MAE: 23.9673, MAPE: 12.6468
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Signal_Line', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AAPL - RMSE: 35.8547, MSE: 1285.5578, MAE: 31.7939, MAPE: 17.0234
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Signal_Line', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 36.7607, MSE: 1351.3519, MAE: 32.7848, MAPE: 17.6013
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Upper_BB', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 18.3987, MSE: 338.5128, MAE: 15.4822, MAPE: 9.3977
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Upper_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 36.6177, MSE: 1340.8560, MAE: 32.1422, MAPE: 19.2132
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Upper_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 27.6953, MSE: 767.0282, MAE: 24.0803, MAPE: 12.8910
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Upper_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 28.8275, MSE: 831.0254, MAE: 24.2445, MAPE: 13.0173
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Upper_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 61.4408, MSE: 3774.9763, MAE: 58.0364, MAPE: 31.9115
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Upper_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 15.9366, MSE: 253.9738, MAE: 12.9586, MAPE: 7.4111
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Lower_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 17.3034, MSE: 299.4093, MAE: 13.9910, MAPE: 7.5407
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Lower_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 23.4580, MSE: 550.2793, MAE: 19.3017, MAPE: 10.2174
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Lower_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 16.5192, MSE: 272.8833, MAE: 13.4429, MAPE: 7.7436
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Lower_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 25.8647, MSE: 668.9818, MAE: 21.7994, MAPE: 11.6486
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Lower_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 11.9646, MSE: 143.1526, MAE: 9.8855, MAPE: 6.0080
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'CCI', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 29.0490, MSE: 843.8451, MAE: 24.6976, MAPE: 13.1300
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'CCI', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 18.9417, MSE: 358.7879, MAE: 15.1974, MAPE: 8.2377
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'CCI', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 28.9333, MSE: 837.1372, MAE: 24.9226, MAPE: 13.2859
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'CCI', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 15.5670, MSE: 242.3326, MAE: 13.0139, MAPE: 7.0233
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'ATR', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 34.8518, MSE: 1214.6466, MAE: 29.5834, MAPE: 15.6306
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'ATR', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 30.0527, MSE: 903.1647, MAE: 25.0979, MAPE: 13.2402
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'ATR', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 45.0426, MSE: 2028.8353, MAE: 40.5069, MAPE: 21.7731
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'ROC', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 22.1933, MSE: 492.5430, MAE: 18.0181, MAPE: 9.7464
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'ROC', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AAPL - RMSE: 24.1365, MSE: 582.5728, MAE: 21.2908, MAPE: 11.6191
#
# Training with indicators: ('20MA', '50MA', 'RSI', 'Williams_%R', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 33.2603, MSE: 1106.2465, MAE: 30.2320, MAPE: 16.3787
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Signal_Line', 'Upper_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 13.7218, MSE: 188.2872, MAE: 11.2618, MAPE: 6.2674
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Signal_Line', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 17.4602, MSE: 304.8569, MAE: 14.5651, MAPE: 8.9257
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Signal_Line', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 38.7193, MSE: 1499.1834, MAE: 33.7565, MAPE: 20.2250
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Signal_Line', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AAPL - RMSE: 36.4432, MSE: 1328.1051, MAE: 31.3809, MAPE: 16.6639
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Signal_Line', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 21.4897, MSE: 461.8090, MAE: 17.2427, MAPE: 9.3680
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Signal_Line', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 21.2351, MSE: 450.9275, MAE: 17.0506, MAPE: 9.2889
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Signal_Line', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 32.3121, MSE: 1044.0717, MAE: 27.6815, MAPE: 16.7453
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Upper_BB', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 25.1440, MSE: 632.2186, MAE: 22.0587, MAPE: 13.3739
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Upper_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 17.5543, MSE: 308.1528, MAE: 14.5686, MAPE: 8.2298
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Upper_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 14.4046, MSE: 207.4924, MAE: 11.4769, MAPE: 6.7194
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Upper_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 19.4978, MSE: 380.1650, MAE: 15.7965, MAPE: 8.7377
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Upper_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 21.0397, MSE: 442.6673, MAE: 16.8543, MAPE: 8.9116
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Upper_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 25.1076, MSE: 630.3900, MAE: 21.2313, MAPE: 11.2947
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Lower_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 20.8632, MSE: 435.2730, MAE: 17.0466, MAPE: 9.1304
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Lower_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 19.9692, MSE: 398.7689, MAE: 16.2971, MAPE: 10.0149
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Lower_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 20.7664, MSE: 431.2425, MAE: 16.5208, MAPE: 8.9088
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Lower_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 36.8061, MSE: 1354.6905, MAE: 32.1368, MAPE: 17.1178
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Lower_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 10.3609, MSE: 107.3488, MAE: 8.5579, MAPE: 4.7788
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'CCI', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 23.4638, MSE: 550.5480, MAE: 19.4533, MAPE: 10.3162
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'CCI', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 22.2787, MSE: 496.3413, MAE: 18.5592, MAPE: 11.4223
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'CCI', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 52.5510, MSE: 2761.6047, MAE: 48.9647, MAPE: 26.8881
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'CCI', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AAPL - RMSE: 12.8495, MSE: 165.1087, MAE: 10.6299, MAPE: 6.0077
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'ATR', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 32.9149, MSE: 1083.3925, MAE: 27.8699, MAPE: 14.8321
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'ATR', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 38.4530, MSE: 1478.6327, MAE: 34.5783, MAPE: 18.7049
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'ATR', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 40.7722, MSE: 1662.3725, MAE: 36.0189, MAPE: 19.3296
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'ROC', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 31.8593, MSE: 1015.0118, MAE: 27.3438, MAPE: 14.4832
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'ROC', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 14.4506, MSE: 208.8193, MAE: 12.0337, MAPE: 7.0715
#
# Training with indicators: ('20MA', '50MA', 'MACD', 'Williams_%R', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 16.1471, MSE: 260.7287, MAE: 13.1781, MAPE: 7.4207
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Upper_BB', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 25.4808, MSE: 649.2730, MAE: 21.3421, MAPE: 12.9338
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Upper_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 35.6432, MSE: 1270.4382, MAE: 32.0577, MAPE: 17.3084
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Upper_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 16.0410, MSE: 257.3131, MAE: 12.6667, MAPE: 6.8665
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Upper_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 17.5266, MSE: 307.1810, MAE: 14.2532, MAPE: 7.9671
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Upper_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 18.9760, MSE: 360.0898, MAE: 15.6330, MAPE: 9.0204
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Upper_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 16.5308, MSE: 273.2679, MAE: 13.7053, MAPE: 8.2610
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Lower_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 15.7133, MSE: 246.9065, MAE: 13.0587, MAPE: 7.5867
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Lower_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 24.5061, MSE: 600.5486, MAE: 20.9095, MAPE: 12.8622
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Lower_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 26.9693, MSE: 727.3442, MAE: 22.2096, MAPE: 11.7944
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Lower_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 17.5885, MSE: 309.3553, MAE: 14.4274, MAPE: 8.2656
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'Lower_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 14.2445, MSE: 202.9044, MAE: 11.7720, MAPE: 6.4844
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'CCI', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 41.7772, MSE: 1745.3377, MAE: 36.6067, MAPE: 19.5032
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'CCI', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 13.8816, MSE: 192.6975, MAE: 11.4254, MAPE: 6.5470
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'CCI', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 37.4910, MSE: 1405.5782, MAE: 34.0465, MAPE: 18.3957
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'CCI', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 23.4760, MSE: 551.1208, MAE: 20.4799, MAPE: 10.9952
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'ATR', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 18.0050, MSE: 324.1788, MAE: 13.9548, MAPE: 7.6684
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'ATR', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 67.4006, MSE: 4542.8435, MAE: 62.7993, MAPE: 34.2787
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'ATR', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 28.9336, MSE: 837.1555, MAE: 25.0528, MAPE: 13.4159
#
# Training with indicators: ('20MA', '50MA', 'Signal_Line', 'ROC', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ...
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 21.0235, MSE: 441.9857, MAE: 17.2058, MAPE: 9.2011
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'Lower_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 16.8257, MSE: 283.1056, MAE: 14.0313, MAPE: 8.3999
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'Lower_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 33.0092, MSE: 1089.6086, MAE: 28.8501, MAPE: 15.4197
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'Lower_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 20.0700, MSE: 402.8047, MAE: 16.0909, MAPE: 8.5872
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'CCI', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 30.0410, MSE: 902.4590, MAE: 25.4863, MAPE: 13.5511
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'CCI', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 38.7335, MSE: 1500.2859, MAE: 34.5804, MAPE: 18.6258
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'CCI', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 29.7641, MSE: 885.9013, MAE: 24.7780, MAPE: 13.0333
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'CCI', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 20.0730, MSE: 402.9257, MAE: 16.3405, MAPE: 8.6652
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'ATR', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 34.8364, MSE: 1213.5766, MAE: 30.1826, MAPE: 16.2156
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'ATR', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 58.9387, MSE: 3473.7692, MAE: 54.6467, MAPE: 29.7372
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'ATR', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 31.2431, MSE: 976.1303, MAE: 26.5619, MAPE: 14.0544
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'ROC', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 19.1214, MSE: 365.6278, MAE: 15.5243, MAPE: 8.3493
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'ROC', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 47.8387, MSE: 2288.5404, MAE: 43.9778, MAPE: 23.8354
#
# Training with indicators: ('50MA', 'RSI', 'Upper_BB', 'Williams_%R', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 32.9500, MSE: 1085.7049, MAE: 28.7252, MAPE: 15.3323
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'CCI', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 20.1489, MSE: 405.9782, MAE: 16.5768, MAPE: 9.5065
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'CCI', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 15.6023, MSE: 243.4323, MAE: 12.5714, MAPE: 7.0686
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'CCI', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 31.5118, MSE: 992.9944, MAE: 27.3080, MAPE: 14.5577
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'CCI', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 30.8964, MSE: 954.5896, MAE: 27.6729, MAPE: 14.9093
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'ATR', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 29.7944, MSE: 887.7060, MAE: 25.0816, MAPE: 13.2127
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'ATR', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 42.4012, MSE: 1797.8608, MAE: 37.8807, MAPE: 20.3200
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'ATR', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 13.0805, MSE: 171.0985, MAE: 10.4127, MAPE: 6.0005
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'ROC', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 21.8725, MSE: 478.4055, MAE: 17.9020, MAPE: 9.4671
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'ROC', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 15.4739, MSE: 239.4405, MAE: 12.9144, MAPE: 7.8714
#
# Training with indicators: ('50MA', 'RSI', 'Lower_BB', 'Williams_%R', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 39.1967, MSE: 1536.3832, MAE: 35.4757, MAPE: 19.1548
#
# Training with indicators: ('50MA', 'RSI', 'CCI', 'ATR', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 30.7887, MSE: 947.9446, MAE: 26.3494, MAPE: 14.0173
#
# Training with indicators: ('50MA', 'RSI', 'CCI', 'ATR', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 37.0131, MSE: 1369.9730, MAE: 31.7945, MAPE: 16.8297
#
# Training with indicators: ('50MA', 'RSI', 'CCI', 'ATR', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 35.8087, MSE: 1282.2661, MAE: 32.1878, MAPE: 17.3602
#
# Training with indicators: ('50MA', 'RSI', 'CCI', 'ROC', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 28.7294, MSE: 825.3809, MAE: 24.2792, MAPE: 12.9129
#
# Training with indicators: ('50MA', 'RSI', 'CCI', 'ROC', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 27.6982, MSE: 767.1909, MAE: 23.1757, MAPE: 12.2490
#
# Training with indicators: ('50MA', 'RSI', 'CCI', 'Williams_%R', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 33.7464, MSE: 1138.8197, MAE: 29.5011, MAPE: 15.7627
#
# Training with indicators: ('50MA', 'RSI', 'ATR', 'ROC', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 59.4425, MSE: 3533.4131, MAE: 55.5825, MAPE: 30.3693
#
# Training with indicators: ('50MA', 'RSI', 'ATR', 'ROC', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 31.1873, MSE: 972.6487, MAE: 26.4273, MAPE: 14.0240
#
# Training with indicators: ('50MA', 'RSI', 'ATR', 'Williams_%R', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 33.5554, MSE: 1125.9631, MAE: 28.4339, MAPE: 15.0653
#
# Training with indicators: ('50MA', 'RSI', 'ROC', 'Williams_%R', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 30.3356, MSE: 920.2488, MAE: 25.8950, MAPE: 13.7322
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Upper_BB', 'Lower_BB') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 14.5812, MSE: 212.6120, MAE: 12.2016, MAPE: 7.0086
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Upper_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 21.8917, MSE: 479.2476, MAE: 18.1734, MAPE: 9.7179
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Upper_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 21.9079, MSE: 479.9572, MAE: 18.2921, MAPE: 9.8348
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Upper_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 20.1457, MSE: 405.8492, MAE: 16.2435, MAPE: 8.8406
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Upper_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 35.1267, MSE: 1233.8866, MAE: 28.6826, MAPE: 15.5365
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Upper_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 14.5208, MSE: 210.8550, MAE: 11.8745, MAPE: 6.5389
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Lower_BB', 'CCI') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 18.0072, MSE: 324.2581, MAE: 15.2109, MAPE: 9.1992
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Lower_BB', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 18.9590, MSE: 359.4422, MAE: 16.0195, MAPE: 9.0500
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Lower_BB', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 15.7838, MSE: 249.1280, MAE: 13.3001, MAPE: 7.8126
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Lower_BB', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 25.6050, MSE: 655.6135, MAE: 20.1489, MAPE: 11.0572
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'Lower_BB', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 21.3837, MSE: 457.2628, MAE: 18.5379, MAPE: 10.9927
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'CCI', 'ATR') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AAPL - RMSE: 16.5728, MSE: 274.6565, MAE: 13.6594, MAPE: 8.0732
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'CCI', 'ROC') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 19.8390, MSE: 393.5869, MAE: 15.8916, MAPE: 8.5953
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'CCI', 'Williams_%R') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AAPL - RMSE: 50.5819, MSE: 2558.5272, MAE: 47.1589, MAPE: 25.8574
#
# Training with indicators: ('50MA', 'MACD', 'Signal_Line', 'CCI', 'OBV') and fixed parameters: {'filters': 64, 'kernel_size': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam'}
